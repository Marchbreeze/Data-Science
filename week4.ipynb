# %% [markdown]
# <a href="https://colab.research.google.com/github/Marchbreeze/KU-Data-Science/blob/main/week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 상관계수

# %%
import pandas as pd
df = pd.read_csv('english.csv')

df
# Out:
#     TOEIC  TEPS  TOEFL
# 0     950   584    119
# 1     695   386    110
# 2     315   142     42
# 3     315   162    103
# 4     270   114     62
# 5     245   195     74
# 6     480   262    107
# 7     555   340     52
# 8     790   483     83
# 9     650   392     90
# 10    635   339    108
# 11    985   592     48
# 12    450   313     41
# 13    430   258    101
# 14    450   317     40
# 15    830   483    103
# 16    595   406     75
# 17    860   473     58
# 18    645   389     41
# 19    840   485     75
# 20    855   522     74
# 21    450   288     87
# 22    205   116     89
# 23    920   527    103
# 24     10    35     58
# 25    440   226    107
# 26     35    68     98
# 27    805   448     81
# 28    280   189    116
# 29    495   316     43

# %%
df_corr = df.corr(method = 'pearson')
df_corr
# Out:
#           TOEIC      TEPS     TOEFL
# TOEIC  1.000000  0.981703  0.065584
# TEPS   0.981703  1.000000  0.022775
# TOEFL  0.065584  0.022775  1.000000

# %%
df_corr = df.corr(method = 'spearman')
df_corr
# Out:
#           TOEIC      TEPS     TOEFL
# TOEIC  1.000000  0.975957  0.063057
# TEPS   0.975957  1.000000  0.017817
# TOEFL  0.063057  0.017817  1.000000

# %%
df_corr = df.corr(method = 'kendall')
df_corr
# Out:
#           TOEIC      TEPS     TOEFL
# TOEIC  1.000000  0.883242  0.034965
# TEPS   0.883242  1.000000  0.018584
# TOEFL  0.034965  0.018584  1.000000

# %% [markdown]
# ## exercise 1

# %%
df = pd.read_csv('animal.csv')
df_corr = df.corr(method = 'pearson')
df_corr
# Out:
#              temperature    height
# temperature     1.000000 -0.999257
# height         -0.999257  1.000000

# %% [markdown]
# # 2. 선형회귀

# %%
import matplotlib.pyplot as plt

# 사이킷런 데이터 분리
from sklearn.model_selection import train_test_split
# 사이킷런 선형 회귀
from sklearn.linear_model import LinearRegression

df = pd.read_csv('score.csv')
df
# Out:
#     StudentNo   1st   2nd   3rd  6mo  9mo  suneung
# 0     STD0001  5.14  1.29  4.19  261  251      300
# 1     STD0002  6.55  5.87  1.99  239  271      299
# 2     STD0003  1.92  1.36  2.14  138  258      299
# 3     STD0004  4.13  5.52  1.73  163  299      298
# 4     STD0005  8.81  2.29  3.61  269  293      297
# ..        ...   ...   ...   ...  ...  ...      ...
# 295   STD0296  1.91  5.69  2.23  245  102      185
# 296   STD0297  1.27  4.92  2.68  172  113      185
# 297   STD0298  1.53  5.21  4.58   65  199      184
# 298   STD0299  1.51  3.44  4.92   48  175      184
# 299   STD0300  4.23  6.99  1.14   20  204      184
#
# [300 rows x 7 columns]

# %%
# 독립변수 x
df_x = df[['1st', '2nd', '3rd', '6mo', '9mo']]
# 종속변수 y
df_y = df['suneung']

# %%
# 학습, 검증 데이터 분리
x_train, x_valid, y_train, y_valid = train_test_split(df_x, df_y, random_state = 0, test_size = 0.20)

# %%
# 선형 회귀 모형 생성
reg = LinearRegression()

# 학습 데이터로 선형 회귀 식에서의 계수 결정
reg.fit(x_train, y_train)

# 학습된 상수항과 회귀 계수 출력
print(reg.intercept_)
print(reg.coef_)
# Out:
# 174.18123037171398
# [ -4.12462039  -7.85273068 -10.95632839   0.2251513    0.52659391]

# %%
# 선형 회귀 모형 생성
y_pred = reg.predict(x_valid)
y_pred
# Out:
# array([223.52732146, 224.97237723, 278.22617706, 225.56972787,
#        203.69507012, 221.95872734, 206.98157694, 198.84623827,
#        265.45563879, 230.24905819, 181.00377126, 258.3184048 ,
#        209.131353  , 213.55556769, 277.34225618, 248.31442747,
#        216.36379344, 261.77779206, 211.98080589, 246.76592418,
#        219.14836521, 242.36642385, 229.19745871, 246.58309307,
#        202.20238607, 255.2829823 , 224.83708533, 201.49959911,
#        198.91363557, 206.06320189, 221.31777721, 248.22851004,
#        258.43314747, 224.07208721, 225.9926627 , 224.39663525,
#        214.85447795, 220.26979407, 201.28146784, 267.31276239,
#        210.91544881, 236.029723  , 239.46806481, 242.33382424,
#        249.79605826, 220.25948958, 216.03915791, 230.40557755,
#        273.24493433, 241.16572666, 270.19805562, 200.29247656,
#        223.4505752 , 235.91082173, 234.98635833, 209.05859773,
#        202.00456442, 286.5585544 , 192.24510093, 206.80776245])
