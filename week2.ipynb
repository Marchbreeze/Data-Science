# %% [markdown]
# <a href="https://colab.research.google.com/github/Marchbreeze/KU-Data-Science/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url1 = 'http://apis.data.go.kr/B553530/BEEC/BEEC_01_LIST?serviceKey='
key = 'FReO6PUa2hf0BpkjjBnfhgwn3bxoEp%2FZj0T7aJh54CGLF4ayyku1UQ%2B6V%2ByzSo6h0k0u66d5O%2BeiCn6Jxnpb3w%3D%3D'
url2 = '&apiType=XML&q1=2022&q2=2022&q3=1&q4=1&q5=9'

url = url1 + key + url2

result = requests.get(url)
result = result.content

# %%
result
# Out:
# b'<?xml version="1.0" encoding="utf-8"?>\r\n<response>\r\n    <header>\r\n        <resultCode>00</resultCode>\r\n        <resultMsg>NORMAL_CODE</resultMsg>\r\n    </header>\r\n    <body>\r\n        <numOfRows>10</numOfRows>\r\n        <pageNo>1</pageNo>\r\n        <totalCount>10</totalCount>\r\n        <items>\r\n            <item>\r\n                <RQID>2021082610</RQID>\r\n                <CRTIF_KIND>\xec\x98\x88\xeb\xb9\x84\xec\x9d\xb8\xec\xa6\x9d</CRTIF_KIND>\r\n                <PURPOSE_KIND_NAME>\xec\xa3\xbc\xea\xb1\xb0\xec\x9a\xa9</PURPOSE_KIND_NAME>\r\n                <BLD_NM>\xea\xb4\x91\xec\xa3\xbc\xea\xb4\x91\xec\x97\xad\xec\x8b\x9c \xea\xb8\x88\xeb\x82\xa8\xeb\xa1\x9c \xed\x95\x9c\xec\x8b\xa0\xeb\x8d\x94\xed\x9c\xb4 \xed\x8e\x9c\xed\x8a\xb8\xed\x95\x98\xec\x9a\xb0\xec\x8a\xa4(\xec\xa3\xbc\xea\xb1\xb0)</BLD_NM>\r\n                <ENTE_NM>NULL</ENTE_NM>\r\n                <GRD_NAME>1+\xeb\x93\xb1\xea\xb8\x89</GRD_NAME>\r\n                <AL_ENGY_REDU_RATE>NULL</AL_ENGY_R
# ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(result, 'lxml-xml')
soup
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
# <header>
# <resultCode>00</resultCode>
# <resultMsg>NORMAL_CODE</resultMsg>
# </header>
# <body>
# <numOfRows>10</numOfRows>
# <pageNo>1</pageNo>
# <totalCount>10</totalCount>
# <items>
# <item>
# <RQID>2021082610</RQID>
# <CRTIF_KIND>예비인증</CRTIF_KIND>
# <PURPOSE_KIND_NAME>주거용</PURPOSE_KIND_NAME>
# <BLD_NM>광주광역시 금남로 한신더휴 펜트하우스(주거)</BLD_NM>
# <ENTE_NM>NULL</ENTE_NM>
# <GRD_NAME>1+등급</GRD_NAME>
# <AL_ENGY_REDU_RATE>NULL</AL_ENGY_REDU_RATE>
# <W_1ST_ENERGY_REQUIRE6>151.4</W_1ST_ENERGY_REQUIRE6>
# <CRTIF_ISU_DD_YEAR>2022</CRTIF_ISU_DD_YEAR>
# <CRTIF_ISU_DD>2022-11-04</CRTIF_ISU_DD>
# <CRTIF_NO>22-주-예-1+-0286</CRTIF_NO>
# <APP_RCPT_ORG_NAME>한국부동산원</APP_RCPT_ORG_NAME>
# <RGN_SCT_NAME>광주</RGN_SCT_NAME>
# <LOC_ADDR>광주 동구 궁동 68-1</LOC_ADDR>
# <HSHLD_NUMB>99</HSHLD_NUMB>
# <AL_EXUS_AREA>11231.32</AL_EXUS_AREA>
# <W_REAL_AREA>NULL</W_REAL_AREA>
# <W_BLD_SCALE>지하4층／지상25층</W_BLD_SCALE>
# <DATA_REG_DT>2024-04-02 12:00:41.0</DATA_REG_DT>
# ...

# %%
import pandas as pd

df = pd.read_xml(result, xpath = './/item')
df
# Out:
#          RQID CRTIF_KIND PURPOSE_KIND_NAME  \
# 0  2021082610       예비인증               주거용
# 1  2021103344       예비인증               주거용
# 2  2021124046       예비인증               주거용
# 3  2022020603       예비인증               주거용
# 4  2022041249       예비인증               주거용
# 5  2022051494       예비인증               주거용
# 6  2022093103       예비인증               주거용
# 7  2022093170       예비인증               주거용
# 8  2022103397       예비인증               주거용
# 9  2022103590       예비인증               주거용
#
#                                   BLD_NM  ENTE_NM GRD_NAME  AL_ENGY_REDU_RATE  \
# 0               광주광역시 금남로 한신더휴 펜트하우스(주거)      NaN     1+등급                NaN
# 1             화정동 23-191 주상복합 신축공사 (아파트)      NaN     1+등급                NaN
# 2            광주광역시 북구 운암동 주상복합 신축공사 (주거)      NaN     1+등급                NaN
# 3  광주광역시 남구 주월동 389-5번지 외 35필지 가로주택 정비사업      NaN     1+등급                NaN
# 4                          신용공원 산이고운 아파트      NaN     1+등급                NaN
# ...

# %%
url1 = 'http://apis.data.go.kr/B553530/BEEC/BEEC_01_LIST?serviceKey='
key = 'FReO6PUa2hf0BpkjjBnfhgwn3bxoEp%2FZj0T7aJh54CGLF4ayyku1UQ%2B6V%2ByzSo6h0k0u66d5O%2BeiCn6Jxnpb3w%3D%3D'
url2 = '&apiType=JSON&q1=2022&q2=2022&q3=1&q4=1&q5=9'

url = url1 + key + url2

result = requests.get(url)
result = result.json()
result
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_CODE'},
#   'body': {'pageNo': '1',
#    'totalCount': '10',
#    'numOfRows': '10',
#    'items': {'item': [{'AL_EXUS_AREA': '11231.32',
#       'W_1ST_ENERGY_REQUIRE6': '151.4',
#       'DATA_REG_DT': '2024-04-02 12:00:41.0',
#       'AL_ENGY_REDU_RATE': 'NULL',
#       'LOC_ADDR': '광주 동구 궁동 68-1',
#       'HSHLD_NUMB': '99',
#       'GRD_NAME': '1+등급',
#       'BLD_NM': '광주광역시 금남로 한신더휴 펜트하우스(주거)',
#       'ENTE_NM': 'NULL',
#       'PURPOSE_KIND_NAME': '주거용',
#       'CRTIF_KIND': '예비인증',
#       'W_BLD_SCALE': '지하4층／지상25층',
#       'W_REAL_AREA': 'NULL',
#       'CRTIF_NO': '22-주-예-1+-0286',
#       'APP_RCPT_ORG_NAME': '한국부동산원',
#       'CRTIF_ISU_DD_YEAR': '2022',
#       'CRTIF_ISU_DD': '2022-11-04',
#       'RQID': '2021082610',
#       'RGN_SCT_NAME': '광주'},
#      {'AL_EXUS_AREA': '11617.1482',
#       'W_1ST_ENERGY_REQUIRE6': '133.3',
#       'DATA_REG_DT': '2024-04-02 12:00:54.0',
# ...

# %%
df = pd.json_normalize(result['response']['body']['items']['item'])
df
# Out:
#   AL_EXUS_AREA W_1ST_ENERGY_REQUIRE6            DATA_REG_DT AL_ENGY_REDU_RATE  \
# 0     11231.32                 151.4  2024-04-02 12:00:41.0              NULL
# 1   11617.1482                 133.3  2024-04-02 12:00:54.0              NULL
# 2   27367.0439                 148.0  2024-04-02 12:00:42.0              NULL
# 3      12959.9                 133.6  2024-04-02 12:00:45.0              NULL
# 4   22479.7043                 133.0  2024-04-02 12:00:48.0              NULL
# 5    43962.948                 146.1  2024-04-02 12:00:47.0              NULL
# 6   89245.1741                 131.8  2024-04-02 12:00:50.0              NULL
# 7   11864.2496                 147.5  2024-04-02 12:00:50.0              NULL
# 8     6015.592                 163.4  2024-04-02 12:00:51.0              NULL
# 9    86412.369                 114.5  2024-04-02 12:00:51.0              NULL
#
#                   LOC_ADDR HSHLD_NUMB GRD_NAME  \
# 0            광주 동구 궁동 68-1         99     1+등급
# ...
