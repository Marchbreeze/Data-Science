# %% [markdown]
# <a href="https://colab.research.google.com/github/Marchbreeze/KU-Data-Science/blob/main/week11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. 지표를 이용한 연관규칙의 분석

# %%
# !pip install mlxtend
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...

# %%
# Apriori Algorithm 적용 위한 라이브러리
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# 데이터 불러오기
df = pd.read_csv('kuflix.csv')
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    나는 SOLO   최강야구  놀면 뭐 하니  환승연애3
# 0     True   True     True  False
# 1    False  False     True   True
# 2     True   True    False   True
# 3    False  False    False   True

# %%
# Apriori Algorithm 적용
result = apriori(df, min_support = 0.5, use_colnames = True)
result
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    support         itemsets
# 0     0.50        (나는 SOLO)
# 1     0.50           (최강야구)
# 2     0.50        (놀면 뭐 하니)
# 3     0.75          (환승연애3)
# 4     0.50  (최강야구, 나는 SOLO)

# %%
# 연관분석을 위한 association_rules
result2 = association_rules(result, metric = 'confidence', min_threshold = 0.5)
result2
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   antecedents consequents  antecedent support  consequent support  support  \
# 0      (최강야구)   (나는 SOLO)                 0.5                 0.5      0.5
# 1   (나는 SOLO)      (최강야구)                 0.5                 0.5      0.5
#
#    confidence  lift  leverage  conviction  zhangs_metric
# 0         1.0   2.0      0.25         inf            1.0
# 1         1.0   2.0      0.25         inf            1.0

# %% [markdown]
# ### Exercise 1

# %%
df2 = pd.read_csv('league.csv')
df2
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     TEEMO  YASUO  BLITZCRANK  VAYNE    ZED  RIVEN  YUUMI
# 0   False   True       False   True  False   True   True
# 1    True   True       False   True   True  False   True
# 2    True   True       False  False   True  False  False
# 3    True  False        True   True   True  False   True
# 4    True  False        True  False   True  False   True
# 5   False   True        True  False  False  False   True
# 6    True  False        True   True  False   True   True
# 7    True   True       False   True  False   True   True
# 8    True  False        True  False   True  False   True
# ...

# %%
result3 = apriori(df2, min_support = 0.4, use_colnames = True)
result3
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     support               itemsets
# 0      0.75                (TEEMO)
# 1      0.55                (YASUO)
# 2      0.70           (BLITZCRANK)
# 3      0.60                (VAYNE)
# 4      0.60                  (ZED)
# 5      0.70                (YUUMI)
# 6      0.50    (TEEMO, BLITZCRANK)
# 7      0.45         (TEEMO, VAYNE)
# 8      0.50           (TEEMO, ZED)
# 9      0.55         (TEEMO, YUUMI)
# 10     0.45      (BLITZCRANK, ZED)
# 11     0.45    (BLITZCRANK, YUUMI)
# 12     0.45         (YUUMI, VAYNE)
# 13     0.40  (TEEMO, YUUMI, VAYNE)

# %%
result4 = association_rules(result3, metric = 'confidence', min_threshold = 0.5)
result4
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        antecedents     consequents  antecedent support  consequent support  \
# 0          (TEEMO)    (BLITZCRANK)                0.75                0.70
# 1     (BLITZCRANK)         (TEEMO)                0.70                0.75
# 2          (TEEMO)         (VAYNE)                0.75                0.60
# 3          (VAYNE)         (TEEMO)                0.60                0.75
# 4          (TEEMO)           (ZED)                0.75                0.60
# 5            (ZED)         (TEEMO)                0.60                0.75
# 6          (TEEMO)         (YUUMI)                0.75                0.70
# ...
